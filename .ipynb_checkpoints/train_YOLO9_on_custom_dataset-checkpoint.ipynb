# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu Mar  7 16:41:54 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.23                 Driver Version: 551.23         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090      WDDM  |   00000000:01:00.0  On |                  Off |
# |  0%   40C    P8             12W /  450W |    1743MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A       488    C+G   ...pdnekdrzrea0\XboxGameBarSpotify.exe      N/A      |
# |    0   N/A  N/A      4224    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A      4956    C+G   ...0.0_x64__cv1g1gvanyjgm\WhatsApp.exe      N/A      |
# |    0   N/A  N/A      5772    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     10012      C   ...er\anaconda3\envs\YoloV9\python.exe      N/A      |
# |    0   N/A  N/A     11228    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     13116    C+G   ...cal\Microsoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     14312    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A     14912    C+G   ...on\122.0.2365.52\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     17684    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     18936    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     19816    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     24972    C+G   ...wekyb3d8bbwe\XboxGameBarWidgets.exe      N/A      |
# |    0   N/A  N/A     25468    C+G   ...__8wekyb3d8bbwe\Notepad\Notepad.exe      N/A      |
# |    0   N/A  N/A     27232    C+G   ...on\122.0.2365.66\msedgewebview2.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# C:\Users\user\Syolo\YoloV9\YoloV9

# %% [markdown]
# ## Clone and Install

# %% [markdown]
# **NOTE:** YOLOv9 is very new. At the moment, we recommend using a fork of the main repository. The `detect.py` script contains a bug that prevents inference. This bug is patched in the fork.

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# Out:
# Cloning into 'yolov9'...

# %%
# !pip install -r yolov9/requirements.txt --user -q
d
# Out:
#   WARNING: The script tqdm.exe is installed in 'C:\Users\user\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy.exe is installed in 'C:\Users\user\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script f2py.exe is installed in 'C:\Users\user\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'C:\Users\user\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\user\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe and torchrun.exe are installed in 'C:\Users\user\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts lsm2bin.exe, tiff2fsspec.exe, tiffcomment.exe and tifffile.exe are installed in 'C:\Users\user\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'C:\Users\user\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts imageio_download_bin.exe and imageio_remove_bin.exe are installed in 'C:\Users\user\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# **NOTE:** Let's install additional packages that will be useful later on.

# %%
# !pip install -q roboflow

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\user\appdata\roaming\python\python311\site-packages (1.26.4)

# %% [markdown]
# ## Imports

# %%
import roboflow

from IPython.display import Image

# %% [markdown]
# ## Download model weights

# %% [markdown]
# **NOTE:** In the YOLOv9 paper, versions yolov9-s and yolov9-m are also mentioned, but the weights for these models are not yet available in the YOLOv9 repository.

# %% [markdown]
# **NOTE:** By default, the results of each subsequent inference sessions are saved in `{HOME}/yolov9/runs/detect/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %% [markdown]
# ## Authenticate and Download the Dataset

# %% [markdown]
# **NOTE:** The dataset must be saved inside the `{HOME}/yolov9` directory, otherwise, the training will not succeed.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="DZr82uud5ZnQ81YazKlz")
project = rf.workspace("project-rice").project("rice-leaf-i1yu9")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in rice-leaf-1 to yolov9:: 100%|█████████████████| 8730/8730 [00:01<00:00, 5252.13it/s]
# Extracting Dataset Version Zip to rice-leaf-1 in yolov9:: 100%|████████████████████| 516/516 [00:00<00:00, 6849.38it/s]

# %%
nvidia-smi --query-gpu=name --format=csv,noheader | wc -l
# Out:
#   Cell In[17], line 1
#     nvidia-smi --query-gpu=name --format=csv,noheader | wc -l
#     ^
# SyntaxError: cannot assign to expression

# %%
# !pip install pickleshare
# Out:
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: pickleshare
# Successfully installed pickleshare-0.7.5

# %% [markdown]
# ## Train Custom Model

# %%
# %cd {HOME}/yolov9
#run in command line 
# python yolov9/train.py --batch 8 --epochs 500 --img 640 --device 0 --min-items 0 --close-mosaic 500 --data ./yolov9/rice-leaf-1/data.yaml --weights ./weights/gelan-c.pt  --cfg ./yolov9/models/detect/gelan-c.yaml  --hyp hyp.scratch-high.yaml
# !python train.py \
--batch 8 --epochs 100 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-e.pt \
--cfg models/detect/gelan-e.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# C:\Users\user\Syolo\YoloV9\YoloV9\yolov9
# C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# train: weights={HOME}/weights/gelan-e.pt, cfg=models/detect/gelan-e.yaml, data={dataset.location}/data.yaml, hyp=hyp.scratch-high.yaml, epochs=100, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Traceback (most recent call last):
#   File "C:\Users\user\Syolo\YoloV9\YoloV9\yolov9\train.py", line 634, in <module>
#     main(opt)
#   File "C:\Users\user\Syolo\YoloV9\YoloV9\yolov9\train.py", line 503, in main
#     check_file(opt.data), check_yaml(opt.cfg), check_yaml(opt.hyp), str(opt.weights), str(opt.project)  # checks
#     ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\Syolo\YoloV9\YoloV9\yolov9\utils\general.py", line 478, in check_file
#     assert len(files), f'File not found: {file}'  # assert file was found
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: File not found: {dataset.location}/data.yaml

# %% [markdown]
# ## Examine Training Results

# %% [markdown]
# **NOTE:** By default, the results of each subsequent training sessions are saved in `{HOME}/yolov9/runs/train/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# confusion_matrix.png				    P_curve.png       train_batch2.jpg
# events.out.tfevents.1709432296.cea7cd620b1c.1581.0  PR_curve.png      val_batch0_labels.jpg
# F1_curve.png					    R_curve.png       val_batch0_pred.jpg
# hyp.yaml					    results.csv       val_batch1_labels.jpg
# labels_correlogram.jpg				    results.png       val_batch1_pred.jpg
# labels.jpg					    train_batch0.jpg  weights
# opt.yaml					    train_batch1.jpg

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp2/results.png", width=1000)

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp2/confusion_matrix.png", width=1000)

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp2/val_batch0_pred.jpg", width=1000)

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 8 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp2/weights/best.pt
# Out:
# /content/yolov9
# val: data=/content/yolov9/rice-leaf-1/data.yaml, weights=['/content/yolov9/runs/train/exp2/weights/best.pt'], batch_size=8, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25413273 parameters, 0 gradients, 102.5 GFLOPs
# val: Scanning /content/yolov9/rice-leaf-1/valid/labels.cache... 51 images, 0 backgrounds, 0 corrupt: 100% 51/51 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.64it/s]
#                    all         51        264      0.419       0.48      0.421      0.159
#       Bacterial_Blight         51         15      0.378      0.333      0.311      0.113
#             Brown_Spot         51        178      0.441      0.601      0.519      0.219
#             Rice_Blast         51         71      0.439      0.507      0.433      0.145
# Speed: 0.2ms pre-process, 36.4ms inference, 25.0ms NMS per image at shape (8, 3, 640, 640)
# Results saved to runs/val/exp

# %% [markdown]
# ## Inference with Custom Model

# %%
# !python detect.py \
--img 640 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp2/weights/best.pt \
--source {dataset.location}/valid/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp2/weights/best.pt'], source=/content/yolov9/rice-leaf-1/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25413273 parameters, 0 gradients, 102.5 GFLOPs
# image 1/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_001_jpg.rf.7cc8e5b14392ef7f51ea3457c0efe164.jpg: 640x640 1 Bacterial_Blight, 3 Brown_Spots, 51.6ms
# image 2/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_002_jpg.rf.f88df0364fa05a396ab7a5fa85bb2867.jpg: 640x640 1 Bacterial_Blight, 1 Brown_Spot, 4 Rice_Blasts, 42.3ms
# image 3/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_003_jpg.rf.a1da26d32e3432a754ee2d68265177f6.jpg: 640x640 1 Rice_Blast, 41.9ms
# image 4/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_021_jpg.rf.9e01054190949cab6318b5e31abcbac3.jpg: 640x640 2 Rice_Blasts, 42.0ms
# image 5/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_026_jpg.rf.8879946706ef2532c02f92794bcf47bb.jpg: 640x640 4 Brown_Spots, 3 Rice_Blasts, 35.5ms
# image 6/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_031_JPG_jpg.rf.0a24d7e2230e0a29124c65bef4ae0da5.jpg: 640x640 2 Brown_Spots, 12 Rice_Blasts, 29.8ms
# image 7/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_036_jpg.rf.4d9754da4af6da127bdb6c6e67799edc.jpg: 640x640 1 Bacterial_Blight, 5 Rice_Blasts, 29.6ms
# image 8/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_041_JPG_jpg.rf.45d373d9617aab223fb382c0cb79eacc.jpg: 640x640 1 Brown_Spot, 2 Rice_Blasts, 29.7ms
# image 9/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_046_jpg.rf.bac8dbf1cf18525c81db0b3d08cd739c.jpg: 640x640 2 Bacterial_Blights, 2 Rice_Blasts, 25.3ms
# image 10/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_049_JPG_jpg.rf.221341cdc55ce2397ca34ec0d535c392.jpg: 640x640 4 Brown_Spots, 9 Rice_Blasts, 24.3ms
# image 11/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_053_JPG_jpg.rf.ab182bef42c6ec0d64bf91f4d624526a.jpg: 640x640 2 Rice_Blasts, 24.8ms
# image 12/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_056_JPG_jpg.rf.6dacda86b019703a8cc7e6e69853bf77.jpg: 640x640 1 Rice_Blast, 25.5ms
# image 13/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_064_JPG_jpg.rf.7a534532cfb7daf2bf4eb7b496d7459e.jpg: 640x640 1 Brown_Spot, 1 Rice_Blast, 25.4ms
# image 14/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_069_JPG_jpg.rf.3c2f88cdc26689242bea654228ed6188.jpg: 640x640 1 Brown_Spot, 2 Rice_Blasts, 24.5ms
# image 15/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_070_JPG_jpg.rf.7a7659cca02a0c365603343d56c94bd9.jpg: 640x640 1 Bacterial_Blight, 3 Rice_Blasts, 25.4ms
# image 16/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_074_jpg.rf.a872dcbc16d91a325ece06280b797443.jpg: 640x640 3 Brown_Spots, 4 Rice_Blasts, 24.7ms
# image 17/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_076_jpg.rf.bd65189a45a307f78fbb368b3ad1e1c6.jpg: 640x640 6 Rice_Blasts, 24.6ms
# image 18/51 /content/yolov9/rice-leaf-1/valid/images/blast_orig_077_jpg.rf.9b6ba92a2ea44911cdab02df7e63a8f0.jpg: 640x640 6 Rice_Blasts, 25.0ms
# image 19/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_008_jpg.rf.099c54a26566c2fb72d32d4c7066d5ae.jpg: 640x640 1 Bacterial_Blight, 25.4ms
# image 20/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_009_JPG_jpg.rf.5b8b1f220a8b24b6471293e3c1a13f48.jpg: 640x640 1 Bacterial_Blight, 24.6ms
# image 21/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_020_jpg.rf.85091b5614451bd402974fe595b5cbde.jpg: 640x640 1 Brown_Spot, 1 Rice_Blast, 25.9ms
# image 22/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_026_jpg.rf.61083304afc3120324984ccf820cfe40.jpg: 640x640 1 Bacterial_Blight, 2 Rice_Blasts, 24.9ms
# image 23/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_036_JPG_jpg.rf.9dd6e4e41d779bf6e23fc87c8c47720e.jpg: 640x640 1 Rice_Blast, 24.7ms
# image 24/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_038_JPG_jpg.rf.4ae3bff8e20dd52248d6e20e363b00a6.jpg: 640x640 1 Bacterial_Blight, 25.2ms
# image 25/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_041_jpg.rf.1532c0fbc30d86af5e521a4746d472c6.jpg: 640x640 (no detections), 24.5ms
# image 26/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_046_jpg.rf.0b07a21951e4065c96c6e67e26420922.jpg: 640x640 (no detections), 25.5ms
# image 27/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_055_jpg.rf.85f9fa0883743c0a6cd2d86d197ffe93.jpg: 640x640 1 Bacterial_Blight, 27.8ms
# image 28/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_062_JPG_jpg.rf.78905b61316fc25514a739717f87672d.jpg: 640x640 2 Bacterial_Blights, 26.9ms
# image 29/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_070_JPG_jpg.rf.b4a38b44a41a838520eeb4767b19d00e.jpg: 640x640 1 Bacterial_Blight, 1 Rice_Blast, 24.6ms
# image 30/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_074_JPG_jpg.rf.8ab4caa7d1d02639bfb8f98e061dc58d.jpg: 640x640 1 Bacterial_Blight, 25.1ms
# image 31/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_076_jpg.rf.627a133314753ef40b19a8a53bd81891.jpg: 640x640 2 Brown_Spots, 24.7ms
# image 32/51 /content/yolov9/rice-leaf-1/valid/images/blight_orig_082_jpg.rf.602186c7037d5b5794e3adc13c226181.jpg: 640x640 3 Brown_Spots, 24.9ms
# image 33/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_004_jpg.rf.49fcf36b57ce21e0d9f2cc5ba0126bea.jpg: 640x640 25 Brown_Spots, 24.7ms
# image 34/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_015_jpg.rf.26e227646e32cd7da0386e58b70b64ce.jpg: 640x640 1 Bacterial_Blight, 3 Brown_Spots, 24.1ms
# image 35/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_021_jpg.rf.bf073050ad4af231158fdecdaf0a8827.jpg: 640x640 1 Brown_Spot, 25.3ms
# image 36/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_027_jpg.rf.e8bd39b508414051d0403581d6b72509.jpg: 640x640 2 Brown_Spots, 25.5ms
# image 37/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_028_jpg.rf.05ac697f71b9381b864f597693f0f034.jpg: 640x640 1 Brown_Spot, 26.7ms
# image 38/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_031_jpg.rf.f877f1ad183d7325147b70469dd7fb4e.jpg: 640x640 2 Brown_Spots, 26.8ms
# image 39/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_032_jpg.rf.eba238a1de6c49398bb32005678a261e.jpg: 640x640 1 Bacterial_Blight, 2 Brown_Spots, 26.7ms
# image 40/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_033_jpg.rf.ab568c31f0d2dddeb97bc64d9d9a360a.jpg: 640x640 1 Rice_Blast, 26.6ms
# image 41/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_037_jpg.rf.eb2d45d224b6f30e1c85f8f925fc3ed7.jpg: 640x640 1 Brown_Spot, 26.2ms
# image 42/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_046_jpg.rf.b38d079a6dcf3fa41ff2e2a129d1aa45.jpg: 640x640 9 Brown_Spots, 34.3ms
# image 43/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_049_jpg.rf.19339ff81cc18651ff95bce3c0960d1a.jpg: 640x640 2 Brown_Spots, 24.4ms
# image 44/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_059_jpg.rf.ae360c429fe122da8b777629f0bbba15.jpg: 640x640 3 Brown_Spots, 1 Rice_Blast, 25.5ms
# image 45/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_062_jpg.rf.14ca1a71f27bb940deef43644900c567.jpg: 640x640 5 Brown_Spots, 25.2ms
# image 46/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_068_jpg.rf.20db062d9a16d42c656d620e189a8b44.jpg: 640x640 5 Brown_Spots, 25.9ms
# image 47/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_070_jpg.rf.d1159155b2153510009ce25e3b3fb970.jpg: 640x640 3 Brown_Spots, 25.6ms
# image 48/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_085_jpg.rf.72a99c144168a3ed1a1ebce077f14b7e.jpg: 640x640 1 Bacterial_Blight, 2 Brown_Spots, 26.7ms
# image 49/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_086_jpg.rf.b4647b44dafc844f7c869249071a99b8.jpg: 640x640 6 Brown_Spots, 25.5ms
# image 50/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_088_jpg.rf.e79594c17e15e8692716f78aed2d628f.jpg: 640x640 4 Brown_Spots, 25.0ms
# image 51/51 /content/yolov9/rice-leaf-1/valid/images/brownspot_orig_098_jpg.rf.da11d5ee82fb5c3ec603ece8334373bc.jpg: 640x640 51 Brown_Spots, 25.7ms
# Speed: 0.5ms pre-process, 27.5ms inference, 11.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp2/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
# %tensorboard --inspect --event_file C:/Users/user/Syolo/YoloV9/YoloV9/runs/train/exp2/events.out.tfevents.1709690207.DESKTOP-GSB1P85.15600.0
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# 2024-03-06 11:51:46.917881: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2024-03-06 11:51:48.741967: E external/local_tsl/tsl/platform/windows/windows_file_system.cc:363] ERROR: GetSymbolicLinkTarget cannot open file for \\?\C:\Users\user\Syolo\YoloV9\YoloV9\runs\train\exp2\events.out.tfevents.1709690207.DESKTOP-GSB1P85.15600.0 GetLastError: 3
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\user\anaconda3\envs\YoloV9\Scripts\tensorboard.exe\__main__.py", line 7, in <module>
#   File "C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\tensorboard\main.py", line 46, in run_main
#     app.run(tensorboard.main, flags_parser=tensorboard.configure)
#   File "C:\Users\user\AppData\Roaming\Python\Python311\site-packages\absl\app.py", line 308, in run
#     _run_main(main, args)
#   File "C:\Users\user\AppData\Roaming\Python\Python311\site-packages\absl\app.py", line 254, in _run_main
#     sys.exit(main(argv))
#              ^^^^^^^^^^
#   File "C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\tensorboard\program.py", line 276, in main
#     return runner(self.flags) or 0
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\tensorboard\program.py", line 289, in _run_serve_subcommand
#     efi.inspect(flags.logdir, event_file, flags.tag)
#   File "C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\tensorboard\backend\event_processing\event_file_inspector.py", line 451, in inspect
#     inspection_units = get_inspection_units(logdir, event_file, tag)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\tensorboard\backend\event_processing\event_file_inspector.py", line 424, in get_inspection_units
#     generator = generator_from_event_file(event_file)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\tensorboard\backend\event_processing\event_file_inspector.py", line 368, in generator_from_event_file
#     return event_file_loader.LegacyEventFileLoader(event_file).Load()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\tensorboard\backend\event_processing\event_file_loader.py", line 136, in __init__
#     self._iterator = _make_tf_record_iterator(self._file_path)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\tensorboard\backend\event_processing\event_file_loader.py", line 82, in _make_tf_record_iterator
#     return tf.compat.v1.io.tf_record_iterator(file_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\tensorflow\python\util\deprecation.py", line 383, in new_func
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\tensorflow\python\lib\io\tf_record.py", line 167, in tf_record_iterator
#     return _pywrap_record_io.RecordIterator(path, compression_type)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tensorflow.python.framework.errors_impl.NotFoundError: NewRandomAccessFile failed to Create/Open: C:/Users/user/Syolo/YoloV9/YoloV9/runs/train/exp2/events.out.tfevents.1709690207.DESKTOP-GSB1P85.15600.0 : The system cannot find the path specified.
#
# ; No such process
# Contents of stdout:
# ======================================================================
# Processing event files... (this can take a few minutes)
# ======================================================================

# %%
# %tensorboard --inspect --event_file "C:/Users/user/Syolo/YoloV9/YoloV9/yolov9/runs/train/exp2/events.out.tfevents.1709690207.DESKTOP-GSB1P85.15600.0"
# Out:
# ERROR: Failed to launch TensorBoard (exited with 0).
# Contents of stderr:
# 2024-03-06 11:54:04.658018: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Contents of stdout:
# ======================================================================
# Processing event files... (this can take a few minutes)
# ======================================================================
#
# These tags are in C:/Users/user/Syolo/YoloV9/YoloV9/yolov9/runs/train/exp2/events.out.tfevents.1709690207.DESKTOP-GSB1P85.15600.0:
# audio -
# histograms -
# images
#    F1_curve
#    PR_curve
#    P_curve
#    R_curve
#    confusion_matrix
#    results
# scalars
#    metrics/mAP_0.5
#    metrics/mAP_0.5:0.95
#    metrics/precision
#    metrics/recall
#    train/box_loss
#    train/cls_loss
#    train/dfl_loss
#    val/box_loss
#    val/cls_loss
#    val/dfl_loss
#    x/lr0
#    x/lr1
#    x/lr2
# tensor -
# ======================================================================
#
# Event statistics for C:/Users/user/Syolo/YoloV9/YoloV9/yolov9/runs/train/exp2/events.out.tfevents.1709690207.DESKTOP-GSB1P85.15600.0:
# audio -
# graph
#    first_step           0
#    last_step            0
#    max_step             0
#    min_step             0
#    num_steps            1
#    outoforder_steps     []
# histograms -
# images
#    first_step           99
#    last_step            99
#    max_step             99
#    min_step             99
#    num_steps            1
#    outoforder_steps     []
# scalars
#    first_step           0
#    last_step            99
#    max_step             99
#    min_step             0
#    num_steps            100
#    outoforder_steps     []
# sessionlog:checkpoint -
# sessionlog:start -
# sessionlog:stop -
# tensor -
# ======================================================================

# %%
DIRECTORY_PATH ="C:/Users/user/Syolo/YoloV9/YoloV9/runs/train/exp2"
print(DIRECTORY_PATH)
# Out:
# C:/Users/user/Syolo/YoloV9/YoloV9/runs/train/exp2

# %%
# %tensorboard --inspect --logdir DIRECTORY_PATH
# Out:
# ERROR: Failed to launch TensorBoard (exited with 0).
# Contents of stderr:
# 2024-03-06 11:53:09.825440: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\YoloV9\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Contents of stdout:
# ======================================================================
# Processing event files... (this can take a few minutes)
# ======================================================================
#
# No event files found within logdir DIRECTORY_PATH

# %%
# %tensorboard --logdir "C:/Users/user/Syolo/YoloV9/YoloV9/yolov9/runs/train/exp2/events.out.tfevents.1709690207.DESKTOP-GSB1P85.15600.0"
# Out:
#       <iframe id="tensorboard-frame-8c3a7b573eaacf37" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8c3a7b573eaacf37");
#           const url = new URL("/", window.location);
#           const port = 6012;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir DIRECTORY_PATH
# Out:
# Reusing TensorBoard on port 6011 (pid 9780), started 0:07:04 ago. (Use '!kill 9780' to kill it.)
#       <iframe id="tensorboard-frame-2d5a18d5f7b1ceb4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2d5a18d5f7b1ceb4");
#           const url = new URL("/", window.location);
#           const port = 6011;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard

# %%
# !pip install tensorflow
# Out:
# ^C

# %%
# !pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in c:\users\user\appdata\roaming\python\python311\site-packages (2.16.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard) (1.62.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard) (3.5.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from tensorboard) (68.2.2)
# Requirement already satisfied: six>1.9 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 5)) (3.1.42)
# Requirement already satisfied: ipython in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from -r requirements.txt (line 6)) (8.20.0)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 7)) (3.8.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 8)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 9)) (4.9.0.80)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from -r requirements.txt (line 10)) (9.5.0)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from -r requirements.txt (line 11)) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from -r requirements.txt (line 12)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from -r requirements.txt (line 13)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 14)) (1.12.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 15)) (0.1.1.post2209072238)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 16)) (4.66.2)
# Requirement already satisfied: tensorboard>=2.4.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 20)) (2.16.2)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 25)) (2.2.1)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 26)) (0.13.2)
# Requirement already satisfied: albumentations>=1.0.3 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 44)) (1.4.0)
# Requirement already satisfied: pycocotools>=2.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 45)) (2.0.7)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from gitpython->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from ipython->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from ipython->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from ipython->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from ipython->-r requirements.txt (line 6)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from ipython->-r requirements.txt (line 6)) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from ipython->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from ipython->-r requirements.txt (line 6)) (5.7.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from ipython->-r requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (2023.7.22)
# Requirement already satisfied: torch in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from thop>=0.1.1->-r requirements.txt (line 15)) (2.0.1+cu117)
# Requirement already satisfied: absl-py>=0.4 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 20)) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 20)) (1.62.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 20)) (3.5.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 20)) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 20)) (68.2.2)
# Requirement already satisfied: six>1.9 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 20)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 20)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 20)) (3.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 25)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python311\site-packages (from pandas>=1.1.4->-r requirements.txt (line 25)) (2024.1)
# Requirement already satisfied: scikit-image>=0.21.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from albumentations>=1.0.3->-r requirements.txt (line 44)) (0.22.0)
# Requirement already satisfied: qudida>=0.0.4 in c:\users\user\appdata\roaming\python\python311\site-packages (from albumentations>=1.0.3->-r requirements.txt (line 44)) (0.0.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from gitdb<5,>=4.0.1->gitpython->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 6)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->-r requirements.txt (line 6)) (0.2.5)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from qudida>=0.0.4->albumentations>=1.0.3->-r requirements.txt (line 44)) (1.4.1.post1)
# Requirement already satisfied: typing-extensions in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from qudida>=0.0.4->albumentations>=1.0.3->-r requirements.txt (line 44)) (4.9.0)
# Requirement already satisfied: opencv-python-headless>=4.0.1 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from qudida>=0.0.4->albumentations>=1.0.3->-r requirements.txt (line 44)) (4.8.0.74)
# Requirement already satisfied: networkx>=2.8 in c:\users\user\appdata\roaming\python\python311\site-packages (from scikit-image>=0.21.0->albumentations>=1.0.3->-r requirements.txt (line 44)) (3.2.1)
# Requirement already satisfied: imageio>=2.27 in c:\users\user\appdata\roaming\python\python311\site-packages (from scikit-image>=0.21.0->albumentations>=1.0.3->-r requirements.txt (line 44)) (2.34.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\user\appdata\roaming\python\python311\site-packages (from scikit-image>=0.21.0->albumentations>=1.0.3->-r requirements.txt (line 44)) (2024.2.12)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\user\appdata\roaming\python\python311\site-packages (from scikit-image>=0.21.0->albumentations>=1.0.3->-r requirements.txt (line 44)) (0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r requirements.txt (line 20)) (2.1.3)
# Requirement already satisfied: executing in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from stack-data->ipython->-r requirements.txt (line 6)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from stack-data->ipython->-r requirements.txt (line 6)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from stack-data->ipython->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: filelock in c:\users\user\appdata\roaming\python\python311\site-packages (from torch->thop>=0.1.1->-r requirements.txt (line 15)) (3.13.1)
# Requirement already satisfied: sympy in c:\users\user\appdata\roaming\python\python311\site-packages (from torch->thop>=0.1.1->-r requirements.txt (line 15)) (1.12)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\envs\yolov9\lib\site-packages (from torch->thop>=0.1.1->-r requirements.txt (line 15)) (3.1.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations>=1.0.3->-r requirements.txt (line 44)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations>=1.0.3->-r requirements.txt (line 44)) (3.3.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\appdata\roaming\python\python311\site-packages (from sympy->torch->thop>=0.1.1->-r requirements.txt (line 15)) (1.3.0)
